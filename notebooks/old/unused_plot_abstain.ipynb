# %%
import matplotlib
import os
import pandas as pd
import pprint


from IPython.display import display, Markdown


from valuebank import *
from measures import *
from plots import *
# Out:
# INFO:datasets:PyTorch version 2.1.2 available.

# %%
var, df = load_run('../controversial_english_us_small/meta-llama_Llama-2-70b-chat-hf/classification-2024-03-11.json')

# %%
plot_topic_stances(var, df)

# %%
stance = 'neutral'
legend_variable = 'model'
var_dfs = [(var, df)]
plot_stance_by_var(var_dfs, stance, legend_variable)

# %%
plot_topic_stance([(var, df)], legend_variable='model', stance='opposes')
